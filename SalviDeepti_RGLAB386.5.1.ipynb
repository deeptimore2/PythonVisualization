# %% [markdown]
# <a href="https://colab.research.google.com/github/deeptimore2/PythonVisualization/blob/main/SalviDeepti_RGLAB386.5.1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# #**R-Guided lab - 386.5.1 -  Plotting Line Styles**
#
# ---
# ## **Lab Overview:**
# <font color="red">**This is a mandatory lab and will be graded. The instructor will walk through the lab during class. Learners must complete and submit it..**</font>
#
# In this lab, we will explore the essential techniques for identifying and applying various line styles using the Matplotlib library in Python. We will demonstrate how to customize visualizations by implementing solid, dashed, dash-dot, and dotted lines within your plots.
#
# ## **Learning Objective:**
#
# By the end of this lesson, learners will be able to:
# - Identify basic line styles (solid, dashed, dash-dot, dotted) in their Matplotlib visualizations.
# - Apply basic line styles (solid, dashed, dash-dot, dotted) in their Matplotlib visualizations.

# %% [markdown]
# ##**Example 1: Dashdot Line style**
#
#
# ### We can use **'dashdot'** value in Linestyle argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

#plt.plot(xpoints, ypoints, linestyle ="dashdot")
plt.plot(xpoints, ypoints, linestyle ="-.")
plt.show()

# %% [markdown]
# ##**Example 2: Dotted Line style**
#
# ### We can use **':'** or **dotted** value in Linestyle argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, linestyle = ":")
plt.show()

# %% [markdown]
# ##**Example 3: Dash Line style**
#
# ### We can use **'--'** or  **dashed** value in Linestyle argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([4, 10])

plt.plot(xpoints, ypoints, linestyle = "--")
plt.show()

# %% [markdown]
# ##**Example 4: Dash Line style**
#
# ### We can use **'-'** or **'solid'** value in Linestyle argument.

# %%
import matplotlib.pyplot as plt
import numpy as np

xpoints = np.array([1, 8])
ypoints = np.array([3, 10])

plt.plot(xpoints, ypoints, linestyle = "-")
plt.show()

# %% [markdown]
# ##**Submission Guidline**
#
# - Submit your completed lab using the Start Assignment button on the assignment page in Canvas.
# - Your submission can be include:
#   - if you are using notebook then, all tasks should be written and submitted in a single notebook file, for example: (**your_name_labname.ipynb**).
#   - if you are using python script file, all tasks should be written and submitted in a single python script file for example: **(your_name_labname.py)**.
# - Add appropriate comments and any additional instructions if required.
